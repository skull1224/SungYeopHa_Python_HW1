# %%
from select import select


memory = []
select = -1
def add(fri):
    memory.append(None)
    klen = len(memory)
    memory[klen-1]=fri
    
def insert(pos,fri):
    if pos<0 or pos>len(katok) :
        print("삭제할 데이터가 없거나 범위가 넘었습니다.")
        return
    memory.append(None)
    klen = len(memory)
    for i in range(klen-1,pos,-1):
        memory[i]=memory[i-1]
        memory[i-1]=None
    memory[pos]=fri
    
     
def Del(pos):
    global memory,head,current,pre
    if pos<0 or pos>len(katok) :
        print("삭제할 데이터가 없거나 범위가 넘었습니다.")
        return
    Len = len(memory)
    memory[pos]=None
    for i in range(pos+1,Len):
        memory[i-1]=memory[i]
        memory[i]=None
    
    del(memory[Len-1])
    
    
    
if __name__ == "__main__" :
    while (select != 4):
        select = int(input("선택하세요(1: 추가, 2: 삽입, 3: 삭제, 4:종료)-->"))
        if (select==1):
            data = input("추가할 데이터 --> ")
            add(data)
            print(memory)
        elif (select==2):
            pos = int(input("삽입할 위치 -->"))
            data = input("추가할 데이터 -->")
            insert(pos,data)
            print(memory)
        elif (select == 3):
            pos = int(input("삭제할 위치 -- > "))
            Del(pos)
            print(memory)
        elif(select == 4):
            print(memory)
            exit
        else :
            print("1~4 중애서 하나 를 입력하시오")
            continue
# Out:
# []

# %%
class Node():
    def __init__(self) :
        self.data=None
        self.link=None
    
global current,pre,haed,memory

def add(data):
    node = Node()
    node.data = data
    node.link = head
    head= node
    
def Del(deldata):
    if head.data==deldata:
        current =head
        head = head.link
        del(current)
        return
    
    current = head
    while current.link != None:
        pre=current
        current = current.link
        if current.data == deldata :
            pre.link = current.link
            del(current)
            return
    
def findadd(finddata, adddata):
    if head.data == finddata :
        node = Node()
        node.data = adddata
        node.link = head
        head = node
        return
    current = head
    while current.link != None :
        pre = current
        current = current.link
        if current.data == finddata:
            node = Node()
            node.data = adddata
            node.link=current
            pre.link = node
            return
        
        
    node = Node()
    node.data = adddata
    current.link=node

        
def printnode(start):
    current = start
    if current ==None:
        return
    print(current.data, end=' ')
    while current.link != None:
        current=current.link
        print(current.data,end='')
    print()
    
    
    memory = []
    head, current,pre=None,None,None
    dataarr = ["다현","정연","쯔위","사나","지효"]
    
    if __name__ == "__main__":
        node = Node()
        node.data = dataarr[0]
        head=node
        memory.append(node)
        for data in dataarr[1:]:
            pre = node
            node = Node()
            node.data = data
            pre.link = node
            memory.append(node)
    
    
    printnode(head)

# %%
class Node():
    def __init__(self) :
        self.data=None
        self.link=None
    
global current,pre,haed,memory

def add(data):
    node = Node()
    node.data = data
    node.link = head
    head= node
    
def Del(deldata):
    if head.data==deldata:
        current =head
        head = head.link
        last = head
        while last.link != current:
            last = last.link
        last.link = head
        del(current)
        return
    
    current = head
    while current.link != None:
        pre=current
        current = current.link
        if current.data == deldata :
            pre.link = current.link
            del(current)
            return
    
def findadd(finddata, adddata):
    if head.data == finddata :
        node = Node()
        node.data = adddata
        node.link = head
        last = head
        while last.link != head:
            last = last.link
        last.link=node
        head = node
        return
    current = head
    while current.link != head :
        pre = current
        current = current.link
        if current.data == finddata:
            node = Node()
            node.data = adddata
            node.link=current
            pre.link = node
            return
        
        
    node = Node()
    node.data = adddata
    current.link=node
    node.link = head
        
def printnode(start):
    current = start
    if current ==None:
        return
    print(current.data, end=' ')
    while current.link != start:
        current=current.link
        print(current.data,end='')
    print()
    
    
    memory = []
    head, current,pre=None,None,None
    dataarr = ["다현","정연","쯔위","사나","지효"]
    
    if __name__ == "__main__":
        node = Node()
        node.data = dataarr[0]
        head=node
        node.link = head
        memory.append(node)
        for data in dataarr[1:]:
            pre = node
            node = Node()
            node.data = data
            pre.link = node
            node.link=head
            memory.append(node)
    
    
    printnode(head)
